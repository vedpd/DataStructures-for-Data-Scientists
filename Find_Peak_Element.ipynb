# %% [markdown]
# <a href="https://colab.research.google.com/github/vedpd/DataStructures-for-Data-Scientists/blob/main/Find_Peak_Element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem statement**
#
# A peak element is an element that is greater than its neighbors.
#
# Given an input array nums, where nums[i] ≠ nums[i+1], find a peak element and return its index.
#
# The array may contain multiple peaks, in that case return the index to any one of the peaks is fine.
#
# You may imagine that nums[-1] = nums[n] = -∞.

# %% [markdown]
# ![Find Peak.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Question reference - Leetcode](https://leetcode.com/problems/find-peak-element/)

# %% [markdown]
# # **Solution 1- Linear Search**:
#
#
#
#
#
# 1.   **Time complexity - O(n)** - as we are traversing through entire elements of list and the time taken will depende on total number of elements of list.
#
# 2.   **Space Complexity - O(1)** - since no new list or array is created, hence it is not dependent on addition of any new element

# %%
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        temp_val=nums[0]
        temp_idx=0
        
        for i in range(0,len(nums),1):
            if(nums[i]>=temp_val):
                temp_val=nums[i]
                temp_idx=i
                
        return temp_idx

# %%
# one more linear search algorithm

class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        n = len(nums)-1
        
        for i in range(0,n):
            if nums[i]>nums[i+1]:
                return i
            
        return n

# %% [markdown]
# # **Solution 2- Binary Search**:
#
#
# 1.   **Time complexity - O(logn)** - as we are traversing through entire elements of list and the time taken will depende on total number of elements of list.
#
# 2.   **Space Complexity - O(1)** - since no new list or array is created, hence it is not dependent on addition of any new element

# %%
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        l=0
        h=len(nums)-1
        
        if(len(nums)==0 or len(nums)==1):
            return 0
        
        while l < h:
            mid=(l+h)//2
            
            if nums[mid]>nums[mid+1]:
                h=mid
            
            if nums[mid]<nums[mid+1]:
                l=mid+1
                
        return l

# %% [markdown]
# Let's understand the binary search case with an example
#
# nums = [1,2,4,2,1]
#
#
# l=0
# h=len(nums)-1 = 5-1 = 4
#
# so l<h:
#
# mid = (0+4)//2 = 2
#
# a[mid] = 4
#
# a[mid+1]= 2
#
# a[mid]>a[mid+1] ? :
#  yes
#  it means that your maxima point is towards the left side and hence we need to reduce our search space.
#
#  Now catch is even your mid can be maxima - which is true here and hence we will shift
#
#  h= mid = 2
#
#
# --- iteration 2 ---
#
# l = 0
# h = 2
# mid = 1
# a[mid]=2
# a[mid+1]=4
#
# is a[mid]>a[mid+1]? = false
# which means now mid has a lower value than element on right, so we need to move low towards right of mid, so that our search space is now [mid+1 , high]
#
# l = mid +1 = 1+1 =2
#
# -----iteration 3----
#
# l= 2, h=2
#  is l<h? - false

# %% [markdown]
# loop breaks and you return l = 2 and that's where value 4 is
#
# ### ** Note: peak's left will be monotonic increasing while its right will be monotonic decreasing.**
